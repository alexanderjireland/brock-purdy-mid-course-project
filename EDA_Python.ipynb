# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
YEAR = 2020

# %%
data = pd.read_csv('https://github.com/nflverse/nflverse-data/releases/download/pbp/' \
                   'play_by_play_' + str(YEAR) + '.csv.gz',
                   compression= 'gzip', low_memory= False)

# %%
data
# Out:
#        play_id         game_id  old_game_id home_team away_team season_type  \
# 0            1  2020_01_ARI_SF   2020091311        SF       ARI         REG
# 1           39  2020_01_ARI_SF   2020091311        SF       ARI         REG
# 2           54  2020_01_ARI_SF   2020091311        SF       ARI         REG
# 3           93  2020_01_ARI_SF   2020091311        SF       ARI         REG
# 4          118  2020_01_ARI_SF   2020091311        SF       ARI         REG
# ...        ...             ...          ...       ...       ...         ...
# 47700     4280   2020_21_KC_TB   2021020700        TB        KC        POST
# 47701     4307   2020_21_KC_TB   2021020700        TB        KC        POST
# 47702     4328   2020_21_KC_TB   2021020700        TB        KC        POST
# 47703     4349   2020_21_KC_TB   2021020700        TB        KC        POST
# 47704     4370   2020_21_KC_TB   2021020700        TB        KC        POST
#
#        week posteam posteam_type defteam  ... out_of_bounds  \
# 0         1     NaN          NaN     NaN  ...             0
# 1         1      SF         home     ARI  ...             0
# 2         1      SF         home     ARI  ...             0
# 3         1      SF         home     ARI  ...             0
# 4         1      SF         home     ARI  ...             0
# ...     ...     ...          ...     ...  ...           ...
# 47700    21      KC         away      TB  ...             0
# 47701    21      TB         home      KC  ...             0
# 47702    21      TB         home      KC  ...             0
# 47703    21      TB         home      KC  ...             0
# 47704    21      TB         home      KC  ...             0
#
#        home_opening_kickoff    qb_epa  xyac_epa  xyac_mean_yardage  \
# 0                         1  0.000000       NaN                NaN
# 1                         1  0.000000       NaN                NaN
# 2                         1  1.294838   0.50337           4.275047
# 3                         1  0.857214       NaN                NaN
# 4                         1 -0.454665       NaN                NaN
# ...                     ...       ...       ...                ...
# 47700                     1 -4.266047       NaN                NaN
# 47701                     1  0.000000       NaN                NaN
# 47702                     1  0.000000       NaN                NaN
# 47703                     1  0.000000       NaN                NaN
# 47704                     1       NaN       NaN                NaN
#
#        xyac_median_yardage xyac_success   xyac_fd     xpass    pass_oe
# 0                      NaN          NaN       NaN       NaN        NaN
# 1                      NaN          NaN       NaN       NaN        NaN
# 2                      2.0     0.619306  0.239695  0.515058  48.494154
# 3                      NaN          NaN       NaN  0.413357 -41.335732
# 4                      NaN          NaN       NaN  0.446920 -44.692025
# ...                    ...          ...       ...       ...        ...
# 47700                  NaN          NaN       NaN  0.904422   9.557813
# 47701                  NaN          NaN       NaN       NaN        NaN
# 47702                  NaN          NaN       NaN       NaN        NaN
# 47703                  NaN          NaN       NaN       NaN        NaN
# 47704                  NaN          NaN       NaN       NaN        NaN
#
# [47705 rows x 372 columns]

# %%
def passer_rating(cmp, yds, tds, ints, att):
    a = (cmp/att - .3) * 5
    b = (yds/att - 3) * .25
    c = (tds/att) * 20
    d = 2.375 - (25 * ints/att)

    return ((a+b+c+d)/6) * 100

def anya(pass_yds, tds, ints, sack_yds, sacks, pass_attempts):
    return (pass_yds + (tds * 20) - (ints * 45) - sack_yds)/(pass_attempts + sacks)

# %%
#decided to focus on passer rating, ANY/A and EPA as stats.
